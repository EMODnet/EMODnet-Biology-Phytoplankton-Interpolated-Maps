# %% [markdown]
# Compute the validator for all the files for different values of $L$.

# %%
using DIVAnd
using PyPlot
using Proj4
using DelimitedFiles
using PyCall
using Dates
using NCDatasets
include("../scripts/PhytoInterp.jl")
include("../scripts/validate_probability.jl")
doplot = true
# Out:
# true

# %% [markdown]
# ## Files and directories

# %%
csvdir = "/data/EMODnet/Biology/phytoplankton/CSV-split/"
datadir = "./data/"
datafilelist = readdir(csvdir);

# List only the analysis files
anaylsisfilelist = [d for d in datafilelist if occursin("analysis", d)]

@info("Working on $(length(anaylsisfilelist)) files");
figdir = "./figures/validation/"
isdir(datadir) ? " " : mkpath(datadir)
isdir(figdir) ? " " : mkpath(figdir);
# Out:
# ┌ Info: Working on 200 files
# └ @ Main In[2]:8

# %% [markdown]
# ## Prepare mask

# %%
longrid = -2.:0.1:10.
latgrid = 51.:0.1:56.
bathname = joinpath(datadir, "gebco_30sec_4.nc")
bx, by, b = load_bath(bathname, true, longrid, latgrid)
mask, (pm, pn),(xi, yi) = DIVAnd.DIVAnd_rectdom(longrid, latgrid);
xi, yi, mask = DIVAnd.load_mask(bathname, true, longrid, latgrid, 0.0);
xx, yy = ndgrid(xi, yi);

# %%
function compute_validator(CLlist, lon, lat, occurs, lonv, latv, occursv)
    
    data_presence = occurs .== 1;
    data_absence = .!(data_presence);
    
    npre = sum(data_presence)
    nabs = sum(data_absence);
    @info("Presence: $(npre), absence: $(nabs)");
    
    inflation = ones(length(lon));
    validatorlist = ones(length(CLlist))
    
    i = 0
    for L in CLlist
        i += 1
        dens2, LHM, LCV, LSCV = DIVAnd_heatmap(mask, (pm,pn), (xx, yy), 
            (lon[data_presence], lat[data_presence]), inflation[data_presence], L, nmax=20000);
        dens3, LHM, LCV, LSCV = DIVAnd_heatmap(mask, (pm,pn), (xx, yy), 
            (lon[data_absence], lat[data_absence]), inflation[data_absence], L, nmax=20000);

        #reldens = dens2 ./ (dens2 .+ dens3);
        reldens = npre .* dens2 ./ (npre .* dens2 .+ nabs .* dens3);

        fieldinterp_valid = reinterp_field(longrid, latgrid, reldens, lonv, latv);

        validator = validate_probability((longrid, latgrid), reldens, (lonv, latv), occursv);
        validatorlist[i] = validator
    end
    return validatorlist
end
# Out:
# compute_validator (generic function with 1 method)

# %% [markdown]
# ## Main loop

# %%
function plot_CL_validator(CLlist::Array, validatorlist::Array, figname)
    fig = PyPlot.figure(figsize=(10, 8))
    plot(CLlist, validatorlist, "ko--")
    xlabel("Correlation length (°)")
    title("Validator ", loc="left", rotation=0, ha="right")
    PyPlot.savefig(figname, dpi=300, bbox_inches="tight")
    PyPlot.close()
end
# Out:
# plot_CL_validator (generic function with 1 method)

# %%
CLlist = [0.05, 0.1, 0.5, 1., 1.5, 2., 5.];
validationfile = "../product/validation_scores_weighted.dat"

# Open file and write tested correlatio lengths
open(validationfile, "w") do io
    write(io, "L", "\t", join(CLlist, "\t"), "\n")

    for datafile in anaylsisfilelist
        speciesname = get_species_name(datafile)
        speciesslug = get_species_slug(datafile)
        @info("Working on $(speciesname)")

        validationfile = replace(datafile, "analysis" => "validation")
        if !isfile(joinpath(csvdir, validationfile))
            @error("Validation file not found")
        end

        # Data reading
        dates, lons, lats, occurs = read_data_phyto(joinpath(csvdir, datafile));
        datesv, lonv, latv, occursv = read_data_phyto(joinpath(csvdir, validationfile));

        # Conversion of coordinates
        # We have to go from `EPSG:32361` to `WGS84`.         
        lon, lat = transform_coords(lons, lats)
        lonv, latv = transform_coords(lonv, latv)

        # Compute heatmap
        inflation = ones(length(lon));

        validatorlist = compute_validator(CLlist, lon, lat, occurs, lonv, latv, occursv);

        figname = joinpath(figdir, "$(speciesslug)_validador_weighted")
        plot_CL_validator(CLlist::Array, validatorlist::Array, figname)

        #println("$(speciesname), $(validatorlist)")
        write(io, speciesname, "\t", join(round.(validatorlist, digits=3), "\t"), "\n")

    end # end of the loop
end
# Out:
# ┌ Info: Working on Actinocyclus octonarius var. octonarius
# └ @ Main In[6]:11
# ┌ Info: Presence: 1173, absence: 7714
# └ @ Main In[4]:8
# ┌ Info: Working on Actinocyclus senarius
# └ @ Main In[6]:11
# ┌ Info: Presence: 3676, absence: 5894
# └ @ Main In[4]:8
# ┌ Info: Working on Actinocyclus
# └ @ Main In[6]:11
# ┌ Info: Presence: 4281, absence: 7069
# └ @ Main In[4]:8
# ┌ Info: Working on Actinoptychus
# └ @ Main In[6]:11
# ┌ Info: Presence: 882, absence: 14536
# └ @ Main In[4]:8
# ┌ Info: Working on Amphidinium
# └ @ Main In[6]:11
# ┌ Info: Presence: 798, absence: 10747
# └ @ Main In[4]:8
# ┌ Info: Working on Archaeperidinium minutum
# └ @ Main In[6]:11
# ┌ Info: Presence: 1113, absence: 6289
# └ @ Main In[4]:8
# ┌ Info: Working on Archaeperidinium
# └ @ Main In[6]:11
# ┌ Info: Presence: 1042, absence: 7400
# └ @ Main In[4]:8
# ┌ Info: Working on Asterionella glacialis
# └ @ Main In[6]:11
# ┌ Info: Presence: 4232, absence: 14861
# └ @ Main In[4]:8
# ┌ Info: Working on Asterionella kariana
# └ @ Main In[6]:11
# ┌ Info: Presence: 1579, absence: 7945
# └ @ Main In[4]:8
# ┌ Info: Working on Asterionella
# └ @ Main In[6]:11
# ┌ Info: Presence: 4722, absence: 15168
# └ @ Main In[4]:8
# ┌ Info: Working on Bacteriastrum hyalinum
# └ @ Main In[6]:11
# ┌ Info: Presence: 1044, absence: 9584
# └ @ Main In[4]:8
# ┌ Info: Working on Bacteriastrum
# └ @ Main In[6]:11
# ┌ Info: Presence: 1376, absence: 19595
# └ @ Main In[4]:8
# ┌ Info: Working on Bellerochea malleus
# └ @ Main In[6]:11
# ┌ Info: Presence: 1362, absence: 15255
# └ @ Main In[4]:8
# ┌ Info: Working on Bellerochea
# └ @ Main In[6]:11
# ┌ Info: Presence: 1720, absence: 16547
# └ @ Main In[4]:8
# ┌ Info: Working on Biddulphia rhombus
# └ @ Main In[6]:11
# ┌ Info: Presence: 1017, absence: 1326
# └ @ Main In[4]:8
# ┌ Info: Working on Biddulphia sinensis
# └ @ Main In[6]:11
# ┌ Info: Presence: 5695, absence: 14488
# └ @ Main In[4]:8
# ┌ Info: Working on Biddulphia
# └ @ Main In[6]:11
# ┌ Info: Presence: 6122, absence: 14882
# └ @ Main In[4]:8
# ┌ Info: Working on Cerataulina bergonii
# └ @ Main In[6]:11
# ┌ Info: Presence: 2511, absence: 11327
# └ @ Main In[4]:8
# ┌ Info: Working on Cerataulina
# └ @ Main In[6]:11
# ┌ Info: Presence: 2586, absence: 11794
# └ @ Main In[4]:8
# ┌ Info: Working on Cerataulus granulata
# └ @ Main In[6]:11
# ┌ Info: Presence: 1182, absence: 13142
# └ @ Main In[4]:8
# ┌ Info: Working on Cerataulus
# └ @ Main In[6]:11
# ┌ Info: Presence: 1225, absence: 16319
# └ @ Main In[4]:8
# ┌ Info: Working on Ceratium fusus
# └ @ Main In[6]:11
# ┌ Info: Presence: 4620, absence: 14058
# └ @ Main In[4]:8
# ┌ Info: Working on Ceratium horridum
# └ @ Main In[6]:11
# ┌ Info: Presence: 2147, absence: 16706
# └ @ Main In[4]:8
# ┌ Info: Working on Ceratium
# └ @ Main In[6]:11
# ┌ Info: Presence: 5522, absence: 14586
# └ @ Main In[4]:8
# ┌ Info: Working on Ceratoneis closterium
# └ @ Main In[6]:11
# ┌ Info: Presence: 737, absence: 254
# └ @ Main In[4]:8
# ┌ Info: Working on Ceratoneis
# └ @ Main In[6]:11
# ┌ Info: Presence: 1676, absence: 8379
# └ @ Main In[4]:8
# ┌ Info: Working on Chaetoceros danicus
# └ @ Main In[6]:11
# ┌ Info: Presence: 1547, absence: 8926
# └ @ Main In[4]:8
# ┌ Info: Working on Chaetoceros debilis
# └ @ Main In[6]:11
# ┌ Info: Presence: 1893, absence: 6809
# └ @ Main In[4]:8
# ┌ Info: Working on Chaetoceros decipiens
# └ @ Main In[6]:11
# ┌ Info: Presence: 1015, absence: 9338
# └ @ Main In[4]:8
# ┌ Info: Working on Chaetoceros densus
# └ @ Main In[6]:11
# ┌ Info: Presence: 1561, absence: 8966
# └ @ Main In[4]:8
# ┌ Info: Working on Chaetoceros didymus
# └ @ Main In[6]:11
# ┌ Info: Presence: 845, absence: 8633
# └ @ Main In[4]:8
# ┌ Info: Working on Chaetoceros socialis
# └ @ Main In[6]:11
# ┌ Info: Presence: 3336, absence: 6051
# └ @ Main In[4]:8
# ┌ Info: Working on Chaetoceros
# └ @ Main In[6]:11
# ┌ Info: Presence: 9653, absence: 10998
# └ @ Main In[4]:8
# ┌ Info: Working on Chattonella
# └ @ Main In[6]:11
# ┌ Info: Presence: 444, absence: 8271
# └ @ Main In[4]:8
# ┌ Info: Working on Chrysochromulina
# └ @ Main In[6]:11
# ┌ Info: Presence: 3492, absence: 6591
# └ @ Main In[4]:8
# ┌ Info: Working on Cochlodinium
# └ @ Main In[6]:11
# ┌ Info: Presence: 684, absence: 6865
# └ @ Main In[4]:8
# ┌ Info: Working on Coscinodiscus angstii var. angstii
# └ @ Main In[6]:11
# ┌ Info: Presence: 844, absence: 7344
# └ @ Main In[4]:8
# ┌ Info: Working on Coscinodiscus concinnus
# └ @ Main In[6]:11
# ┌ Info: Presence: 591, absence: 16605
# └ @ Main In[4]:8
# ┌ Info: Working on Coscinodiscus radiatus
# └ @ Main In[6]:11
# ┌ Info: Presence: 491, absence: 7345
# └ @ Main In[4]:8
# ┌ Info: Working on Coscinodiscus wailesii
# └ @ Main In[6]:11
# ┌ Info: Presence: 1089, absence: 17358
# └ @ Main In[4]:8
# ┌ Info: Working on Coscinodiscus
# └ @ Main In[6]:11
# ┌ Info: Presence: 5208, absence: 15523
# └ @ Main In[4]:8
# ┌ Info: Working on Cyclotella
# └ @ Main In[6]:11
# ┌ Info: Presence: 660, absence: 9594
# └ @ Main In[4]:8
# ┌ Info: Working on Cylindrotheca closterium
# └ @ Main In[6]:11
# ┌ Info: Presence: 4783, absence: 10761
# └ @ Main In[4]:8
# ┌ Info: Working on Cylindrotheca
# └ @ Main In[6]:11
# ┌ Info: Presence: 4759, absence: 11818
# └ @ Main In[4]:8
# ┌ Info: Working on Dictyocha speculum
# └ @ Main In[6]:11
# ┌ Info: Presence: 747, absence: 9162
# └ @ Main In[4]:8
# ┌ Info: Working on Dictyocha
# └ @ Main In[6]:11
# ┌ Info: Presence: 1214, absence: 9562
# └ @ Main In[4]:8
# ┌ Info: Working on Dinobryon
# └ @ Main In[6]:11
# ┌ Info: Presence: 727, absence: 9354
# └ @ Main In[4]:8
# ┌ Info: Working on Dinophysis acuminata
# └ @ Main In[6]:11
# ┌ Info: Presence: 854, absence: 13311
# └ @ Main In[4]:8
# ┌ Info: Working on Dinophysis
# └ @ Main In[6]:11
# ┌ Info: Presence: 1799, absence: 17973
# └ @ Main In[4]:8
# ┌ Info: Working on Diploneis
# └ @ Main In[6]:11
# ┌ Info: Presence: 633, absence: 12825
# └ @ Main In[4]:8
# ┌ Info: Working on Diplopsalis
# └ @ Main In[6]:11
# ┌ Info: Presence: 828, absence: 9710
# └ @ Main In[4]:8
# ┌ Info: Working on Ditylum brightwellii
# └ @ Main In[6]:11
# ┌ Info: Presence: 2924, absence: 14068
# └ @ Main In[4]:8
# ┌ Info: Working on Ditylum
# └ @ Main In[6]:11
# ┌ Info: Presence: 4222, absence: 17919
# └ @ Main In[4]:8
# ┌ Info: Working on Entomoneis
# └ @ Main In[6]:11
# ┌ Info: Presence: 646, absence: 8627
# └ @ Main In[4]:8
# ┌ Info: Working on Ethmodiscus
# └ @ Main In[6]:11
# ┌ Info: Presence: 183, absence: 1684
# └ @ Main In[4]:8
# ┌ Info: Working on Eucampia striata
# └ @ Main In[6]:11
# ┌ Info: Presence: 970, absence: 10494
# └ @ Main In[4]:8
# ┌ Info: Working on Eucampia zodiacus
# └ @ Main In[6]:11
# ┌ Info: Presence: 2329, absence: 16535
# └ @ Main In[4]:8
# ┌ Info: Working on Eucampia
# └ @ Main In[6]:11
# ┌ Info: Presence: 2735, absence: 17383
# └ @ Main In[4]:8
# ┌ Info: Working on Euglena
# └ @ Main In[6]:11
# ┌ Info: Presence: 109, absence: 7129
# └ @ Main In[4]:8
# ┌ Info: Working on Eunotogramma dubium
# └ @ Main In[6]:11
# ┌ Info: Presence: 2776, absence: 7078
# └ @ Main In[4]:8
# ┌ Info: Working on Eunotogramma
# └ @ Main In[6]:11
# ┌ Info: Presence: 2924, absence: 8077
# └ @ Main In[4]:8
# ┌ Info: Working on Eupodiscus
# └ @ Main In[6]:11
# ┌ Info: Presence: 643, absence: 7568
# └ @ Main In[4]:8
# ┌ Info: Working on Eutreptiella
# └ @ Main In[6]:11
# ┌ Info: Presence: 2527, absence: 6330
# └ @ Main In[4]:8
# ┌ Info: Working on Fibrocapsa
# └ @ Main In[6]:11
# ┌ Info: Presence: 844, absence: 9212
# └ @ Main In[4]:8
# ┌ Info: Working on Fragilaria
# └ @ Main In[6]:11
# ┌ Info: Presence: 1603, absence: 16824
# └ @ Main In[4]:8
# ┌ Info: Working on Gonyaulax
# └ @ Main In[6]:11
# ┌ Info: Presence: 933, absence: 18691
# └ @ Main In[4]:8
# ┌ Info: Working on Gymnodinium simplex
# └ @ Main In[6]:11
# ┌ Info: Presence: 633, absence: 5139
# └ @ Main In[4]:8
# ┌ Info: Working on Gymnodinium
# └ @ Main In[6]:11
# ┌ Info: Presence: 2032, absence: 8513
# └ @ Main In[4]:8
# ┌ Info: Working on Gyrodinium spirale
# └ @ Main In[6]:11
# ┌ Info: Presence: 3136, absence: 5977
# └ @ Main In[4]:8
# ┌ Info: Working on Gyrodinium
# └ @ Main In[6]:11
# ┌ Info: Presence: 5565, absence: 6945
# └ @ Main In[4]:8
# ┌ Info: Working on Gyrosigma
# └ @ Main In[6]:11
# ┌ Info: Presence: 1372, absence: 16577
# └ @ Main In[4]:8
# ┌ Info: Working on Helicotheca tamesis
# └ @ Main In[6]:11
# ┌ Info: Presence: 1078, absence: 11469
# └ @ Main In[4]:8
# ┌ Info: Working on Helicotheca
# └ @ Main In[6]:11
# ┌ Info: Presence: 1100, absence: 13514
# └ @ Main In[4]:8
# ┌ Info: Working on Heterocapsa minima
# └ @ Main In[6]:11
# ┌ Info: Presence: 2758, absence: 4385
# └ @ Main In[4]:8
# ┌ Info: Working on Heterocapsa rotundata
# └ @ Main In[6]:11
# ┌ Info: Presence: 1177, absence: 2329
# └ @ Main In[4]:8
# ┌ Info: Working on Heterocapsa triquetra
# └ @ Main In[6]:11
# ┌ Info: Presence: 784, absence: 8730
# └ @ Main In[4]:8
# ┌ Info: Working on Heterocapsa
# └ @ Main In[6]:11
# ┌ Info: Presence: 5595, absence: 5400
# └ @ Main In[4]:8
# ┌ Info: Working on Katodinium glaucum
# └ @ Main In[6]:11
# ┌ Info: Presence: 3068, absence: 5040
# └ @ Main In[4]:8
# ┌ Info: Working on Katodinium
# └ @ Main In[6]:11
# ┌ Info: Presence: 3036, absence: 7510
# └ @ Main In[4]:8
# ┌ Info: Working on Lauderia annulata
# └ @ Main In[6]:11
# ┌ Info: Presence: 2195, absence: 16586
# └ @ Main In[4]:8
# ┌ Info: Working on Lauderia
# └ @ Main In[6]:11
# ┌ Info: Presence: 2145, absence: 16727
# └ @ Main In[4]:8
# ┌ Info: Working on Leptocylindrus danicus
# └ @ Main In[6]:11
# ┌ Info: Presence: 3232, absence: 15028
# └ @ Main In[4]:8
# ┌ Info: Working on Leptocylindrus minimus
# └ @ Main In[6]:11
# ┌ Info: Presence: 1861, absence: 6670
# └ @ Main In[4]:8
# ┌ Info: Working on Leptocylindrus
# └ @ Main In[6]:11
# ┌ Info: Presence: 4574, absence: 15742
# └ @ Main In[4]:8
# ┌ Info: Working on Leucocryptos marina
# └ @ Main In[6]:11
# ┌ Info: Presence: 1738, absence: 4640
# └ @ Main In[4]:8
# ┌ Info: Working on Leucocryptos
# └ @ Main In[6]:11
# ┌ Info: Presence: 2400, absence: 7421
# └ @ Main In[4]:8
# ┌ Info: Working on Lithodesmium undulatum
# └ @ Main In[6]:11
# ┌ Info: Presence: 1405, absence: 8911
# └ @ Main In[4]:8
# ┌ Info: Working on Lithodesmium
# └ @ Main In[6]:11
# ┌ Info: Presence: 1596, absence: 10580
# └ @ Main In[4]:8
# ┌ Info: Working on Mediopyxis helysia
# └ @ Main In[6]:11
# ┌ Info: Presence: 1277, absence: 2631
# └ @ Main In[4]:8
# ┌ Info: Working on Mediopyxis
# └ @ Main In[6]:11
# ┌ Info: Presence: 1120, absence: 3230
# └ @ Main In[4]:8
# ┌ Info: Working on Melosira
# └ @ Main In[6]:11
# ┌ Info: Presence: 753, absence: 7728
# └ @ Main In[4]:8
# ┌ Info: Working on Mesodinium rubrum
# └ @ Main In[6]:11
# ┌ Info: Presence: 3226, absence: 5645
# └ @ Main In[4]:8
# ┌ Info: Working on Mesodinium
# └ @ Main In[6]:11
# ┌ Info: Presence: 3121, absence: 6640
# └ @ Main In[4]:8
# ┌ Info: Working on Mesoporos
# └ @ Main In[6]:11
# ┌ Info: Presence: 462, absence: 7750
# └ @ Main In[4]:8
# ┌ Info: Working on Micromonas
# └ @ Main In[6]:11
# ┌ Info: Presence: 1228, absence: 2360
# └ @ Main In[4]:8
# ┌ Info: Working on Minutocellus
# └ @ Main In[6]:11
# ┌ Info: Presence: 731, absence: 5214
# └ @ Main In[4]:8
# ┌ Info: Working on Monoraphidium
# └ @ Main In[6]:11
# ┌ Info: Presence: 677, absence: 6952
# └ @ Main In[4]:8
# ┌ Info: Working on Navicula
# └ @ Main In[6]:11
# ┌ Info: Presence: 4193, absence: 17899
# └ @ Main In[4]:8
# ┌ Info: Working on Nitzschia longissima
# └ @ Main In[6]:11
# ┌ Info: Presence: 869, absence: 5400
# └ @ Main In[4]:8
# ┌ Info: Working on Nitzschia
# └ @ Main In[6]:11
# ┌ Info: Presence: 2041, absence: 14551
# └ @ Main In[4]:8
# ┌ Info: Working on Noctiluca scintillans
# └ @ Main In[6]:11
# ┌ Info: Presence: 2844, absence: 16583
# └ @ Main In[4]:8
# ┌ Info: Working on Noctiluca
# └ @ Main In[6]:11
# ┌ Info: Presence: 3115, absence: 18354
# └ @ Main In[4]:8
# ┌ Info: Working on Oblea
# └ @ Main In[6]:11
# ┌ Info: Presence: 578, absence: 7191
# └ @ Main In[4]:8
# ┌ Info: Working on Odontella aurita
# └ @ Main In[6]:11
# ┌ Info: Presence: 3778, absence: 16300
# └ @ Main In[4]:8
# ┌ Info: Working on Odontella mobiliensis
# └ @ Main In[6]:11
# ┌ Info: Presence: 635, absence: 14288
# └ @ Main In[4]:8
# ┌ Info: Working on Odontella regia
# └ @ Main In[6]:11
# ┌ Info: Presence: 1718, absence: 15014
# └ @ Main In[4]:8
# ┌ Info: Working on Odontella
# └ @ Main In[6]:11
# ┌ Info: Presence: 4516, absence: 15501
# └ @ Main In[4]:8
# ┌ Info: Working on Orthosira marina
# └ @ Main In[6]:11
# ┌ Info: Presence: 4179, absence: 3292
# └ @ Main In[4]:8
# ┌ Info: Working on Orthosira
# └ @ Main In[6]:11
# ┌ Info: Presence: 4743, absence: 4602
# └ @ Main In[4]:8
# ┌ Info: Working on Oxytoxum
# └ @ Main In[6]:11
# ┌ Info: Presence: 583, absence: 5841
# └ @ Main In[4]:8
# ┌ Info: Working on Paralia sulcata
# └ @ Main In[6]:11
# ┌ Info: Presence: 4916, absence: 6761
# └ @ Main In[4]:8
# ┌ Info: Working on Paralia
# └ @ Main In[6]:11
# ┌ Info: Presence: 5099, absence: 7843
# └ @ Main In[4]:8
# ┌ Info: Working on Pediastrum
# └ @ Main In[6]:11
# ┌ Info: Presence: 532, absence: 8373
# └ @ Main In[4]:8
# ┌ Info: Working on Peridiniella
# └ @ Main In[6]:11
# ┌ Info: Presence: 592, absence: 6826
# └ @ Main In[4]:8
# ┌ Info: Working on Peridinium achromaticum
# └ @ Main In[6]:11
# ┌ Info: Presence: 1231, absence: 6222
# └ @ Main In[4]:8
# ┌ Info: Working on Peridinium
# └ @ Main In[6]:11
# ┌ Info: Presence: 1028, absence: 7111
# └ @ Main In[4]:8
# ┌ Info: Working on Phaeoceros
# └ @ Main In[6]:11
# ┌ Info: Presence: 2323, absence: 6332
# └ @ Main In[4]:8
# ┌ Info: Working on Phaeocystis globosa
# └ @ Main In[6]:11
# ┌ Info: Presence: 1121, absence: 890
# └ @ Main In[4]:8
# ┌ Info: Working on Phaeocystis
# └ @ Main In[6]:11
# ┌ Info: Presence: 9967, absence: 13769
# └ @ Main In[4]:8
# ┌ Info: Working on Phalacroma rotundatum
# └ @ Main In[6]:11
# ┌ Info: Presence: 753, absence: 11695
# └ @ Main In[4]:8
# ┌ Info: Working on Phalacroma
# └ @ Main In[6]:11
# ┌ Info: Presence: 806, absence: 16128
# └ @ Main In[4]:8
# ┌ Info: Working on Plagiogramma brockmanni var. brockmanni
# └ @ Main In[6]:11
# ┌ Info: Presence: 4399, absence: 4800
# └ @ Main In[4]:8
# ┌ Info: Working on Plagiogramma vanheurckii
# └ @ Main In[6]:11
# ┌ Info: Presence: 2024, absence: 5966
# └ @ Main In[4]:8
# ┌ Info: Working on Plagiogramma
# └ @ Main In[6]:11
# ┌ Info: Presence: 5728, absence: 5918
# └ @ Main In[4]:8
# ┌ Info: Working on Pleurosigma
# └ @ Main In[6]:11
# ┌ Info: Presence: 3718, absence: 7566
# └ @ Main In[4]:8
# ┌ Info: Working on Podosira stelligera
# └ @ Main In[6]:11
# ┌ Info: Presence: 1217, absence: 15306
# └ @ Main In[4]:8
# ┌ Info: Working on Podosira
# └ @ Main In[6]:11
# ┌ Info: Presence: 1312, absence: 15675
# └ @ Main In[4]:8
# ┌ Info: Working on Polykrikos schwartzii
# └ @ Main In[6]:11
# ┌ Info: Presence: 1058, absence: 14377
# └ @ Main In[4]:8
# ┌ Info: Working on Polykrikos
# └ @ Main In[6]:11
# ┌ Info: Presence: 1475, absence: 17119
# └ @ Main In[4]:8
# ┌ Info: Working on Preperidinium
# └ @ Main In[6]:11
# ┌ Info: Presence: 713, absence: 9926
# └ @ Main In[4]:8
# ┌ Info: Working on Proboscia alata
# └ @ Main In[6]:11
# ┌ Info: Presence: 1290, absence: 15299
# └ @ Main In[4]:8
# ┌ Info: Working on Proboscia
# └ @ Main In[6]:11
# ┌ Info: Presence: 1310, absence: 17459
# └ @ Main In[4]:8
# ┌ Info: Working on Prorocentrum cordatum
# └ @ Main In[6]:11
# ┌ Info: Presence: 1197, absence: 8375
# └ @ Main In[4]:8
# ┌ Info: Working on Prorocentrum micans
# └ @ Main In[6]:11
# ┌ Info: Presence: 2146, absence: 11800
# └ @ Main In[4]:8
# ┌ Info: Working on Prorocentrum triestinum
# └ @ Main In[6]:11
# ┌ Info: Presence: 1544, absence: 8298
# └ @ Main In[4]:8
# ┌ Info: Working on Prorocentrum
# └ @ Main In[6]:11
# ┌ Info: Presence: 3854, absence: 16680
# └ @ Main In[4]:8
# ┌ Info: Working on Protoperidinium bipes
# └ @ Main In[6]:11
# ┌ Info: Presence: 2535, absence: 6807
# └ @ Main In[4]:8
# ┌ Info: Working on Protoperidinium
# └ @ Main In[6]:11
# ┌ Info: Presence: 7252, absence: 14186
# └ @ Main In[4]:8
# ┌ Info: Working on Pseudo
# └ @ Main In[6]:11
# ┌ Info: Presence: 3024, absence: 13826
# └ @ Main In[4]:8
# ┌ Info: Working on Pseudo
# └ @ Main In[6]:11
# ┌ Info: Presence: 1080, absence: 4871
# └ @ Main In[4]:8
# ┌ Info: Working on Pseudo
# └ @ Main In[6]:11
# ┌ Info: Presence: 1884, absence: 4586
# └ @ Main In[4]:8
# ┌ Info: Working on Pseudo
# └ @ Main In[6]:11
# ┌ Info: Presence: 1786, absence: 13474
# └ @ Main In[4]:8
# ┌ Info: Working on Pseudo
# └ @ Main In[6]:11
# ┌ Info: Presence: 7519, absence: 12482
# └ @ Main In[4]:8
# ┌ Info: Working on Pseudopedinella
# └ @ Main In[6]:11
# ┌ Info: Presence: 933, absence: 6826
# └ @ Main In[4]:8
# ┌ Info: Working on Pterosperma
# └ @ Main In[6]:11
# ┌ Info: Presence: 847, absence: 15749
# └ @ Main In[4]:8
# ┌ Info: Working on Pyramimonas
# └ @ Main In[6]:11
# ┌ Info: Presence: 3814, absence: 7410
# └ @ Main In[4]:8
# ┌ Info: Working on Ralfsiella minima
# └ @ Main In[6]:11
# ┌ Info: Presence: 2064, absence: 5996
# └ @ Main In[4]:8
# ┌ Info: Working on Ralfsiella
# └ @ Main In[6]:11
# ┌ Info: Presence: 1974, absence: 6904
# └ @ Main In[4]:8
# ┌ Info: Working on Rhaphoneis amphiceros
# └ @ Main In[6]:11
# ┌ Info: Presence: 1954, absence: 15215
# └ @ Main In[4]:8
# ┌ Info: Working on Rhaphoneis minutissima
# └ @ Main In[6]:11
# ┌ Info: Presence: 2273, absence: 3770
# └ @ Main In[4]:8
# ┌ Info: Working on Rhaphoneis
# └ @ Main In[6]:11
# ┌ Info: Presence: 3724, absence: 14170
# └ @ Main In[4]:8
# ┌ Info: Working on Rhizosolenia delicatula
# └ @ Main In[6]:11
# ┌ Info: Presence: 5619, absence: 12191
# └ @ Main In[4]:8
# ┌ Info: Working on Rhizosolenia flaccida
# └ @ Main In[6]:11
# ┌ Info: Presence: 3353, absence: 15186
# └ @ Main In[4]:8
# ┌ Info: Working on Rhizosolenia fragilissima f. fragilissima
# └ @ Main In[6]:11
# ┌ Info: Presence: 1655, absence: 17075
# └ @ Main In[4]:8
# ┌ Info: Working on Rhizosolenia hebetata
# └ @ Main In[6]:11
# ┌ Info: Presence: 941, absence: 8177
# └ @ Main In[4]:8
# ┌ Info: Working on Rhizosolenia imbricata
# └ @ Main In[6]:11
# ┌ Info: Presence: 2044, absence: 7692
# └ @ Main In[4]:8
# ┌ Info: Working on Rhizosolenia setigera
# └ @ Main In[6]:11
# ┌ Info: Presence: 4656, absence: 14993
# └ @ Main In[4]:8
# ┌ Info: Working on Rhizosolenia shrubsolei
# └ @ Main In[6]:11
# ┌ Info: Presence: 3206, absence: 4212
# └ @ Main In[4]:8
# ┌ Info: Working on Rhizosolenia stolterfothii
# └ @ Main In[6]:11
# ┌ Info: Presence: 1169, absence: 5148
# └ @ Main In[4]:8
# ┌ Info: Working on Rhizosolenia styliformis
# └ @ Main In[6]:11
# ┌ Info: Presence: 1559, absence: 15855
# └ @ Main In[4]:8
# ┌ Info: Working on Rhizosolenia
# └ @ Main In[6]:11
# ┌ Info: Presence: 11595, absence: 9901
# └ @ Main In[4]:8
# ┌ Info: Working on Scenedesmus
# └ @ Main In[6]:11
# ┌ Info: Presence: 1425, absence: 6693
# └ @ Main In[4]:8
# ┌ Info: Working on Scrippsiella
# └ @ Main In[6]:11
# ┌ Info: Presence: 3035, absence: 16961
# └ @ Main In[4]:8
# ┌ Info: Working on Skeletonema costatum
# └ @ Main In[6]:11
# ┌ Info: Presence: 3295, absence: 13471
# └ @ Main In[4]:8
# ┌ Info: Working on Skeletonema
# └ @ Main In[6]:11
# ┌ Info: Presence: 4928, absence: 15330
# └ @ Main In[4]:8
# ┌ Info: Working on Stauroneis membranacea
# └ @ Main In[6]:11
# ┌ Info: Presence: 826, absence: 6934
# └ @ Main In[4]:8
# ┌ Info: Working on Stauroneis
# └ @ Main In[6]:11
# ┌ Info: Presence: 833, absence: 7259
# └ @ Main In[4]:8
# ┌ Info: Working on Stephanopyxis turris
# └ @ Main In[6]:11
# ┌ Info: Presence: 733, absence: 8699
# └ @ Main In[4]:8
# ┌ Info: Working on Stephanopyxis
# └ @ Main In[6]:11
# ┌ Info: Presence: 654, absence: 15919
# └ @ Main In[4]:8
# ┌ Info: Working on Subsilicea
# └ @ Main In[6]:11
# ┌ Info: Presence: 764, absence: 5222
# └ @ Main In[4]:8
# ┌ Info: Working on Syndendrium
# └ @ Main In[6]:11
# ┌ Info: Presence: 600, absence: 9606
# └ @ Main In[4]:8
# ┌ Info: Working on Synedra nitzschioides f. nitzschioides
# └ @ Main In[6]:11
# ┌ Info: Presence: 5492, absence: 12960
# └ @ Main In[4]:8
# ┌ Info: Working on Synedra
# └ @ Main In[6]:11
# ┌ Info: Presence: 5762, absence: 15554
# └ @ Main In[4]:8
# ┌ Info: Working on Teleaulax
# └ @ Main In[6]:11
# ┌ Info: Presence: 563, absence: 1216
# └ @ Main In[4]:8
# ┌ Info: Working on Thalassiosira decipiens
# └ @ Main In[6]:11
# ┌ Info: Presence: 689, absence: 2588
# └ @ Main In[4]:8
# ┌ Info: Working on Thalassiosira eccentrica
# └ @ Main In[6]:11
# ┌ Info: Presence: 541, absence: 5678
# └ @ Main In[4]:8
# ┌ Info: Working on Thalassiosira levanderi
# └ @ Main In[6]:11
# ┌ Info: Presence: 1004, absence: 4092
# └ @ Main In[4]:8
# ┌ Info: Working on Thalassiosira nordenskioeldii
# └ @ Main In[6]:11
# ┌ Info: Presence: 943, absence: 9132
# └ @ Main In[4]:8
# ┌ Info: Working on Thalassiosira rotula
# └ @ Main In[6]:11
# ┌ Info: Presence: 1723, absence: 5633
# └ @ Main In[4]:8
# ┌ Info: Working on Thalassiosira
# └ @ Main In[6]:11
# ┌ Info: Presence: 10774, absence: 10004
# └ @ Main In[4]:8
# ┌ Info: Working on Tintinnopsis
# └ @ Main In[6]:11
# ┌ Info: Presence: 391, absence: 804
# └ @ Main In[4]:8
# ┌ Info: Working on Torodinium robustum
# └ @ Main In[6]:11
# ┌ Info: Presence: 3239, absence: 6122
# └ @ Main In[4]:8
# ┌ Info: Working on Torodinium
# └ @ Main In[6]:11
# ┌ Info: Presence: 2870, absence: 6753
# └ @ Main In[4]:8
# ┌ Info: Working on Triceratium alternans f. alternans
# └ @ Main In[6]:11
# ┌ Info: Presence: 2168, absence: 16072
# └ @ Main In[4]:8
# ┌ Info: Working on Triceratium
# └ @ Main In[6]:11
# ┌ Info: Presence: 2133, absence: 17865
# └ @ Main In[4]:8
# ┌ Info: Working on Trieres regia
# └ @ Main In[6]:11
# ┌ Info: Presence: 787, absence: 866
# └ @ Main In[4]:8
# ┌ Info: Working on Trieres
# └ @ Main In[6]:11
# ┌ Info: Presence: 844, absence: 1596
# └ @ Main In[4]:8
# ┌ Info: Working on Tripodiscus
# └ @ Main In[6]:11
# ┌ Info: Presence: 577, absence: 6502
# └ @ Main In[4]:8
# ┌ Info: Working on Tripos furca
# └ @ Main In[6]:11
# ┌ Info: Presence: 1880, absence: 14719
# └ @ Main In[4]:8
# ┌ Info: Working on Tripos lineatus
# └ @ Main In[6]:11
# ┌ Info: Presence: 1103, absence: 17078
# └ @ Main In[4]:8
# ┌ Info: Working on Tripos longipes
# └ @ Main In[6]:11
# ┌ Info: Presence: 745, absence: 13871
# └ @ Main In[4]:8
# ┌ Info: Working on Tripos macroceros
# └ @ Main In[6]:11
# ┌ Info: Presence: 1855, absence: 14429
# └ @ Main In[4]:8
# ┌ Info: Working on Tripos muelleri
# └ @ Main In[6]:11
# ┌ Info: Presence: 2681, absence: 16142
# └ @ Main In[4]:8
# ┌ Info: Working on Tripos
# └ @ Main In[6]:11
# ┌ Info: Presence: 5050, absence: 14539
# └ @ Main In[4]:8
# ┌ Info: Working on Vibrio paxillifer
# └ @ Main In[6]:11
# ┌ Info: Presence: 1134, absence: 16685
# └ @ Main In[4]:8
# ┌ Info: Working on Vibrio
# └ @ Main In[6]:11
# ┌ Info: Presence: 1200, absence: 18444
# └ @ Main In[4]:8
# ┌ Info: Working on Warnowia
# └ @ Main In[6]:11
# ┌ Info: Presence: 807, absence: 6399
# └ @ Main In[4]:8
# ┌ Info: Working on Zygoceros rhombus
# └ @ Main In[6]:11
# ┌ Info: Presence: 974, absence: 16145
# └ @ Main In[4]:8
# ┌ Info: Working on Zygoceros surirella
# └ @ Main In[6]:11
# ┌ Info: Presence: 996, absence: 7285
# └ @ Main In[4]:8
# ┌ Info: Working on Zygoceros
# └ @ Main In[6]:11
# ┌ Info: Presence: 2175, absence: 17187
# └ @ Main In[4]:8
